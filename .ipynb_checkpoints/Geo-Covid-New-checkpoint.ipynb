# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
my_df=pd.read_csv('covid-vaccination-vs-death_ratio.csv')  

my_df2=pd.read_csv('owid-covid-data.csv')


my_df3=pd.read_csv('vaccinations.csv')    # https://www.kaggle.com/gpreda/covid-world-vaccination-progress


thirdworld_df=pd.read_csv("list_of_least_developed_countries_as_of_december_2018_uo7hWUb.csv")

variants_df=pd.read_csv("covid-variants.csv")   # https://www.kaggle.com/gpreda/covid-19-variants-in-romania

# %%
print(min(my_df['date']))
print(max(my_df['date']))

print(min(my_df2['date']))
print(max(my_df2['date']))

print(min(my_df3['date']))
print(max(my_df3['date']))
print("\n")
print(min(variants_df['date']))
print(max(variants_df['date']))
print("\n")
# print(min(df_merged['date']))
# print(max(df_merged['date']))
# Out:
# 2020-12-13
# 2021-12-26
# 2020-01-01
# 2021-06-28
# 2020-12-02
# 2022-02-22
#
#
# 2020-05-11
# 2022-01-05

# %%
# my_df3.dtypes
# my_df3['date'] = pd.to_datetime(my_df3['date'])

# %%
variants_df
# Out:
#         location        date         variant  num_sequences  perc_sequences  \
# 0         Angola  2020-07-06           Alpha              0             0.0
# 1         Angola  2020-07-06       B.1.1.277              0             0.0
# 2         Angola  2020-07-06       B.1.1.302              0             0.0
# 3         Angola  2020-07-06       B.1.1.519              0             0.0
# 4         Angola  2020-07-06         B.1.160              0             0.0
# ...          ...         ...             ...            ...             ...
# 100411  Zimbabwe  2021-11-01         Omicron              0             0.0
# 100412  Zimbabwe  2021-11-01   S:677H.Robin1              0             0.0
# 100413  Zimbabwe  2021-11-01  S:677P.Pelican              0             0.0
# 100414  Zimbabwe  2021-11-01          others              0             0.0
# 100415  Zimbabwe  2021-11-01         non_who              0             0.0
#
#         num_sequences_total
# ...

# %%
my_df
# Out:
#        Unnamed: 0      country iso_code        date  total_vaccinations  \
# 0               0  Afghanistan      AFG  2021-05-11            504502.0
# 1               1  Afghanistan      AFG  2021-05-20            547901.0
# 2               2  Afghanistan      AFG  2021-05-24            573277.0
# 3               3  Afghanistan      AFG  2021-05-26            590454.0
# 4               4  Afghanistan      AFG  2021-05-27            593313.0
# ...           ...          ...      ...         ...                 ...
# 26618       26618     Zimbabwe      ZWE  2021-12-22           7167610.0
# 26619       26619     Zimbabwe      ZWE  2021-12-23           7188128.0
# 26620       26620     Zimbabwe      ZWE  2021-12-24           7200776.0
# 26621       26621     Zimbabwe      ZWE  2021-12-25           7209049.0
# 26622       26622     Zimbabwe      ZWE  2021-12-26           7214640.0
#
#        people_vaccinated  people_fully_vaccinated  New_deaths  population  \
# ...

# %%
my_df2
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 98899      ZWE    Africa     Zimbabwe  2021-06-24      44306.0      826.0
# 98900      ZWE    Africa     Zimbabwe  2021-06-25      45217.0      911.0
# 98901      ZWE    Africa     Zimbabwe  2021-06-26      46018.0      801.0
# 98902      ZWE    Africa     Zimbabwe  2021-06-27      46442.0      424.0
# 98903      ZWE    Africa     Zimbabwe  2021-06-28      47284.0      842.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
my_df3
# Out:
#           location iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 84346     Zimbabwe      ZWE  2022-02-18           7810556.0
# 84347     Zimbabwe      ZWE  2022-02-19           7820885.0
# 84348     Zimbabwe      ZWE  2022-02-20           7823894.0
# 84349     Zimbabwe      ZWE  2022-02-21           7829096.0
# 84350     Zimbabwe      ZWE  2022-02-22           7836325.0
#
#        people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                    0.0                      NaN             NaN
# 1                    NaN                      NaN             NaN
# ...

# %%
# fill nans of daily vaccination with 0 and also daily vaccinations per hundred

my_df3['daily_people_vaccinated'] = my_df3['daily_people_vaccinated'].fillna(0)

my_df3['daily_people_vaccinated_per_hundred'] = my_df3['daily_people_vaccinated_per_hundred'].fillna(0)


my_df3['daily_vaccinations_per_million'] = my_df3['daily_vaccinations_per_million'].fillna(0)

my_df3['daily_vaccinations_per_million'] = my_df3['daily_vaccinations_per_million'].fillna(0)



my_df3 = my_df3.drop(['daily_vaccinations_raw'], 1)

# %%
my_df3.loc[my_df3["location"]=="Afghanistan"]
# Out:
#         location iso_code        date  total_vaccinations  people_vaccinated  \
# 0    Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1    Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2    Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3    Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4    Afghanistan      AFG  2021-02-26                 NaN                NaN
# ..           ...      ...         ...                 ...                ...
# 359  Afghanistan      AFG  2022-02-16                 NaN                NaN
# 360  Afghanistan      AFG  2022-02-17                 NaN                NaN
# 361  Afghanistan      AFG  2022-02-18                 NaN                NaN
# 362  Afghanistan      AFG  2022-02-19                 NaN                NaN
# 363  Afghanistan      AFG  2022-02-20           5412309.0          4801524.0
#
# ...

# %%
# delete from my df dates that dont exist at variants dataset and vise versa
# 2020-12-13
# 2021-12-26

# 2020-12-07
# 2022-01-05


# me to deftero dataset afto
# my_final_df = my_df3.loc[(my_df3['date'] <= '2022-01-05')]
# final_variants_df = variants_df.loc[(variants_df['date'] >= '2020-12-02')]


# me to proto dataset afto


mask = (variants_df['date'] >= '2020-12-13') & (variants_df['date'] <= '2021-12-26')


final_variants_df = variants_df.loc[mask]


mask2 = (my_df['date'] >= '2020-12-21') & (my_df['date'] <= '2021-12-13')


final_variants_df = variants_df.loc[mask]

my_df = my_df.loc[mask2]


# print(min(my_final_df['date']))
# print(max(my_final_df['date']))



print(min(my_df['date']))
print(max(my_df['date']))
print("\n")
print(min(variants_df['date']))
print(max(variants_df['date']))
print("\n")
print(min(final_variants_df['date']))
print(max(final_variants_df['date']))
# Out:
# 2020-12-21
# 2021-12-13
#
#
# 2020-05-11
# 2022-01-05
#
#
# 2020-12-21
# 2021-12-13

# %%
# df_merged = pd.merge(my_df3, variants_df, on=['date', 'location'], how='inner')


my_df.rename(columns={'country': 'location'}, inplace=True)

my_df
# Out:
# /home/kostas/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#        Unnamed: 0     location iso_code        date  total_vaccinations  \
# 0               0  Afghanistan      AFG  2021-05-11            504502.0
# 1               1  Afghanistan      AFG  2021-05-20            547901.0
# 2               2  Afghanistan      AFG  2021-05-24            573277.0
# 3               3  Afghanistan      AFG  2021-05-26            590454.0
# 4               4  Afghanistan      AFG  2021-05-27            593313.0
# ...           ...          ...      ...         ...                 ...
# 26605       26605     Zimbabwe      ZWE  2021-12-09           6871310.0
# ...

# %%
my_df['daily_vac'] = my_df['total_vaccinations'].diff()
my_df
# Out:
# /home/kostas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Unnamed: 0     location iso_code        date  total_vaccinations  \
# 0               0  Afghanistan      AFG  2021-05-11            504502.0
# 1               1  Afghanistan      AFG  2021-05-20            547901.0
# 2               2  Afghanistan      AFG  2021-05-24            573277.0
# 3               3  Afghanistan      AFG  2021-05-26            590454.0
# 4               4  Afghanistan      AFG  2021-05-27            593313.0
# ...           ...          ...      ...         ...                 ...
# ...

# %%
df_merged2 = pd.merge(my_df, final_variants_df, on=['date', 'location'], how='inner')


df_merged2

print(min(df_merged2['date']))
print(max(df_merged2['date']))
# Out:
# 2020-12-21
# 2021-12-13

# %%
thirdworld_df
#thirdcountries = thirdworld_df['Country Name'].tolist()
# Out:
#                         Country name di_id  LDC status marker (1=LDC)
# 0                        Afghanistan    AF                          1
# 1                             Angola    AO                          1
# 2                         Bangladesh    BD                          1
# 3                              Benin    BJ                          1
# 4                             Bhutan    BT                          1
# 5                       Burkina Faso    BF                          1
# 6                            Burundi    BI                          1
# 7                           Cambodia    KH                          1
# 8           Central African Republic    CF                          1
# 9                               Chad    TD                          1
# 10                           Comoros    KM                          1
# 11  Democratic Republic of the Congo    CD                          1
# ...

# %%
thirdcountries = thirdworld_df['Country name'].tolist()
df_merged2['Third world']=False

# %%
thirdcountries
# Out:
# ['Afghanistan',
#  'Angola',
#  'Bangladesh',
#  'Benin',
#  'Bhutan',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Central African Republic',
#  'Chad',
#  'Comoros',
#  'Democratic Republic of the Congo',
#  'Djibouti',
#  'Eritrea',
#  'Ethiopia',
#  'Gambia',
#  'Guinea',
#  'Guinea-Bissau',
#  'Haiti',
#  'Kiribati',
#  'Laos',
#  'Lesotho',
#  'Liberia',
#  'Madagascar',
#  'Malawi',
#  'Mali',
#  'Mauritania',
#  'Mozambique',
#  'Myanmar',
#  'Nepal',
#  'Niger',
#  'Rwanda',
#  'S�o Tom� and Pr�ncipe',
#  'Senegal',
#  'Sierra Leone',
#  'Solomon Islands',
#  'Somalia',
#  'South Sudan',
#  'Sudan',
#  'Timor-Leste',
#  'Togo',
#  'Tuvalu',
#  'Uganda',
#  'Tanzania',
#  'Vanuatu',
#  'Yemen',
#  'Zambia']

# %%
for index, row in df_merged2.iterrows():
    if row["location"] in thirdcountries:
        print(row["location"])
        df_merged2.at[index,'Third world'] = True
        #row["Third world"]=1
# Out:
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Angola
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# Bangladesh
# ...

# %%
thirdworld_df
df_merged2
for col in df_merged2.columns:
    print(col)
    
    
df=df_merged2
df.describe()
# Out:
# Unnamed: 0
# location
# iso_code
# date
# total_vaccinations
# people_vaccinated
# people_fully_vaccinated
# New_deaths
# population
# ratio
# daily_vac
# variant
# num_sequences
# perc_sequences
# num_sequences_total
# Third world
#          Unnamed: 0  total_vaccinations  people_vaccinated  \
# count  32088.000000        3.208800e+04       3.208800e+04
# mean   12821.818250        2.664335e+07       1.674650e+07
# std     7220.148161        9.083542e+07       6.168041e+07
# min      225.000000        1.000000e+00       1.000000e+00
# 25%     6614.000000        8.806740e+05       6.136770e+05
# 50%    12680.000000        4.519495e+06       2.899188e+06
# 75%    19023.000000        1.743081e+07       1.067015e+07
# max    26568.000000        1.335466e+09       8.179076e+08
#
#        people_fully_vaccinated    New_deaths    population         ratio  \
# count             3.208800e+04  32088.000000  3.208800e+04  32088.000000
# ...

# %%
# df['vacc_rat'] = my_df['people_fully_vaccinated']/my_df['population']
# df['new_death_rat'] = my_df['New_deaths']/my_df['population']

# %%
df
# Out:
#        Unnamed: 0  location iso_code        date  total_vaccinations  \
# 0             225    Angola      AGO  2021-05-31            909215.0
# 1             225    Angola      AGO  2021-05-31            909215.0
# 2             225    Angola      AGO  2021-05-31            909215.0
# 3             225    Angola      AGO  2021-05-31            909215.0
# 4             225    Angola      AGO  2021-05-31            909215.0
# ...           ...       ...      ...         ...                 ...
# 32083       26568  Zimbabwe      ZWE  2021-11-01           5923317.0
# 32084       26568  Zimbabwe      ZWE  2021-11-01           5923317.0
# 32085       26568  Zimbabwe      ZWE  2021-11-01           5923317.0
# 32086       26568  Zimbabwe      ZWE  2021-11-01           5923317.0
# 32087       26568  Zimbabwe      ZWE  2021-11-01           5923317.0
#
#        people_vaccinated  people_fully_vaccinated  New_deaths  population  \
# ...

# %%
df2 = df[['location','date','New_deaths', 'vacc_rat','new_death_rat', 'Third world', 'people_fully_vaccinated','population']]

# %%
my_df2.corr(method ='kendall')
# Out:
#                          New_deaths  vacc_rat  new_death_rat  Third world  \
# New_deaths                 1.000000 -0.127666       0.606523    -0.107067
# vacc_rat                  -0.127666  1.000000      -0.117436    -0.164947
# new_death_rat              0.606523 -0.117436       1.000000    -0.161344
# Third world               -0.107067 -0.164947      -0.161344     1.000000
# people_fully_vaccinated    0.304753  0.386948       0.045088    -0.067748
# population                 0.505174 -0.122185       0.113252     0.081302
#
#                          people_fully_vaccinated  population
# New_deaths                              0.304753    0.505174
# vacc_rat                                0.386948   -0.122185
# new_death_rat                           0.045088    0.113252
# Third world                            -0.067748    0.081302
# people_fully_vaccinated                 1.000000    0.493692
# population                              0.493692    1.000000

# %%
my_df2.corr(method ='kendall')
# Out:
#                          New_deaths  vacc_rat  new_death_rat  Third world  \
# New_deaths                 1.000000 -0.127666       0.606523    -0.107067
# vacc_rat                  -0.127666  1.000000      -0.117436    -0.164947
# new_death_rat              0.606523 -0.117436       1.000000    -0.161344
# Third world               -0.107067 -0.164947      -0.161344     1.000000
# people_fully_vaccinated    0.304753  0.386948       0.045088    -0.067748
# population                 0.505174 -0.122185       0.113252     0.081302
#
#                          people_fully_vaccinated  population
# New_deaths                              0.304753    0.505174
# vacc_rat                                0.386948   -0.122185
# new_death_rat                           0.045088    0.113252
# Third world                            -0.067748    0.081302
# people_fully_vaccinated                 1.000000    0.493692
# population                              0.493692    1.000000

# %%
corrMatrix = my_df2.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
date=my_df2["date"]
max1 = date.max(axis=0)
min1 = date.max(axis=0)

# %%
print(max1)
print(min1)
# Out:
# 2021-12-26
# 2021-12-26
